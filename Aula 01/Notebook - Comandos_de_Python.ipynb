# %% [markdown]
# ## Curso de Extensão - Python para PLN - USP

# %% [markdown]
# **Esse** é um *programa* de teste

# %%
print('Hello World')
# Out:
# Hello World

# %%
1 + 1
# Out:
# 2

# %%
'fernandes' + ' macedo'
# Out:
# 'fernandes macedo'

# %%
x = 4 + 6
x
# Out:
# 10

# %%
x = 5 + 9
x
# Out:
# 14

# %%
y = "fernandes macedo"
y
# Out:
# 'fernandes macedo'

# %%
k = 1.8 - 1.5
k
# Out:
# 0.30000000000000004

# %%
type(y)
# Out:
# str

# %%
type(k)
# Out:
# float

# %%
type(x)
# Out:
# int

# %%
x >= 14
# Out:
# True

# %%
v = "1"
q = "1"
v + q
# Out:
# '11'

# %%
l = [0, 1, 2, 3, 4]
l
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# append: insere um elemento no final da lista

# %%
# insere um elemento no final da lista
l.append(5)
l
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
# insere um elemento na posição requerida
l.insert(2,6)
l
# Out:
# [0, 1, 6, 2, 3, 4, 5]

# %%
l.reverse()
l
# Out:
# [5, 4, 3, 2, 6, 1, 0]

# %%
l.sort()
l
# Out:
# [0, 1, 2, 3, 4, 5, 6]
